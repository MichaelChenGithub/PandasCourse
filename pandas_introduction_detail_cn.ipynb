# %%
import pandas as pd

# %% [markdown]
# ### 建立 Dataframe

# %% [markdown]
# #### 使用 dictionary 建立

# %%
dic = {
    "PassengerId": [1, 3, 5],
    "name": ['Braund, Mr. Owen Harris', 'Heikkinen, Miss. Laina', 'Allen, Mr. William Henry'], 
    "sex": ['male', 'female', 'male'],
}
dic_df = pd.DataFrame(dic)
dic_df
# Out:
#    PassengerId                      name     sex
# 0            1   Braund, Mr. Owen Harris    male
# 1            3    Heikkinen, Miss. Laina  female
# 2            5  Allen, Mr. William Henry    male

# %% [markdown]
#     #### 載入資料

# %%
train = pd.read_csv('train.csv', chunksize=200)
train_df = pd.DataFrame()
for chunk in train:
    train_df = pd.concat([train_df, chunk], ignore_index=True)
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df = pd.read_csv('train.csv')
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### 剪貼簿貼上

# %% [markdown]
# ### DataFrame 顯示 & 相關資訊

# %% [markdown]
# #### 顯示部分 DataFrame

# %%
train_df.head() # 括號中可以輸入想要看幾筆資料，預設為 5 筆
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.tail() # 括號中可以輸入想要看幾筆資料，預設為 5 筆
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #### 完整顯示 DataFrame

# %%
pd.set_option("display.max_row", None) # 若要完整顯示所有 columns -> "display.max_columns"

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
pd.set_option("display.max_row", 25) # 為避免影響後續操作美觀，我們還是先調回來吧~

# %% [markdown]
# #### DataFrame 的基本訊息

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #### DataFrame 中數值型變數的基本統計

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### 資料處理與轉換

# %% [markdown]
# #### 選取

# %%
train_df.Cabin # train_df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
train_df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
train_df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df[['PassengerId','Cabin']]
# Out:
#      PassengerId Cabin
# 0              1   NaN
# 1              2   C85
# 2              3   NaN
# 3              4  C123
# 4              5   NaN
# ..           ...   ...
# 886          887   NaN
# 887          888   B42
# 888          889   NaN
# 889          890  C148
# 890          891   NaN
#
# [891 rows x 2 columns]

# %%
train_df.loc[:, 'Name':'Fare']
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare
# ...

# %% [markdown]
# #### 新增欄位

# %%
train_df['new_col'] = 1
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.loc[:,'new_col2'] = 2
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### 刪除欄位

# %%
train_df = train_df.drop(columns=['new_col', 'new_col2', 'SibSp', 'Parch'])
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
mask = (train_df['Survived'] == 1) & (train_df['Pclass'] == 3)
train_df[mask].style.applymap(lambda x: 'background-color: blue', 
              subset=pd.IndexSlice[:, 'Survived':'Pclass'])
# Out:
# <style type="text/css">
# ...

# %%
mask = train_df['Name'].str.contains('Mr')
train_df[mask].style.applymap(lambda x: 'background-color: blue', 
              subset=pd.IndexSlice[:, 'Name'])
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# #### 修改欄位

# %% [markdown]
# ##### fillna 函式補值

# %%
train_df['Age'] = train_df['Age'].fillna(20)

# %%
train_df['Age'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### apply 函式對每一個樣本做自定義運算

# %% [markdown]
# ###### 自訂義 function

# %%
def get_personal_title(s):
    s = s.split(',')[1]
    s = s.split('.')[0]
    s = s.strip()
    return s

train_df['personal_title'] = train_df['Name'].apply(get_personal_title)

# %%
train_df[['PassengerId', 'Name', 'personal_title']]
# Out:
#      PassengerId                                               Name  \
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
#     personal_title
# 0               Mr
# 1              Mrs
# 2             Miss
# 3              Mrs
# 4               Mr
# ..             ...
# ...

# %% [markdown]
# ###### lambda 函式

# %%
median_fare = train_df['Fare'].median()
train_df['fare_grade'] = train_df['Fare'].apply(lambda x: 'low' if x < median_fare else 'high')
train_df[['PassengerId', 'Fare', 'fare_grade']]
# Out:
#      PassengerId     Fare fare_grade
# 0              1   7.2500        low
# 1              2  71.2833       high
# 2              3   7.9250        low
# 3              4  53.1000       high
# 4              5   8.0500        low
# ..           ...      ...        ...
# 886          887  13.0000        low
# 887          888  30.0000       high
# 888          889  23.4500       high
# 889          890  30.0000       high
# 890          891   7.7500        low
#
# [891 rows x 3 columns]

# %% [markdown]
# ##### mask 依條件賦值

# %%
train_df['chinese_sex'] = train_df['Sex'].mask(train_df['Sex'] == 'male', '男生')
train_df['chinese_sex'] = train_df['chinese_sex'].mask(train_df['Sex'] == 'female', '女生')
train_df[['PassengerId', 'Sex', 'chinese_sex']]
# Out:
#      PassengerId     Sex chinese_sex
# 0              1    male          男生
# 1              2  female          女生
# 2              3  female          女生
# 3              4  female          女生
# 4              5    male          男生
# ..           ...     ...         ...
# 886          887    male          男生
# 887          888  female          女生
# 888          889  female          女生
# 889          890    male          男生
# 890          891    male          男生
#
# [891 rows x 3 columns]

# %% [markdown]
# ##### astype 修改資料型別

# %%
train_df['Age'] = train_df['Age'].astype(int)
train_df[['PassengerId', 'Name','Age']]
# Out:
#      PassengerId                                               Name  Age
# 0              1                            Braund, Mr. Owen Harris   22
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...   38
# 2              3                             Heikkinen, Miss. Laina   26
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)   35
# 4              5                           Allen, Mr. William Henry   35
# ..           ...                                                ...  ...
# 886          887                              Montvila, Rev. Juozas   27
# 887          888                       Graham, Miss. Margaret Edith   19
# 888          889           Johnston, Miss. Catherine Helen "Carrie"   20
# 889          890                              Behr, Mr. Karl Howell   26
# 890          891                                Dooley, Mr. Patrick   32
#
# [891 rows x 3 columns]

# %%
labels = [f'{i}年齡層' for i in ['低', '中', '高']]
train_df['Age_group'] = pd.cut(x=train_df['Age'], bins=3, labels=labels)
train_df[['PassengerId', 'Age', 'Age_group']]
# Out:
#      PassengerId   Age Age_group
# 0              1  22.0      低年齡層
# 1              2  38.0      中年齡層
# 2              3  26.0      低年齡層
# 3              4  35.0      中年齡層
# 4              5  35.0      中年齡層
# ..           ...   ...       ...
# 886          887  27.0      中年齡層
# 887          888  19.0      低年齡層
# 888          889   NaN       NaN
# 889          890  26.0      低年齡層
# 890          891  32.0      中年齡層
#
# [891 rows x 3 columns]

# %% [markdown]
# ##### groupby

# %%
train_df.groupby(['Pclass', 'Sex'])['Name'].apply(list).reset_index()
# Out:
#    Pclass     Sex                                               Name
# 0       1  female  [Cumings, Mrs. John Bradley (Florence Briggs T...
# 1       1    male  [McCarthy, Mr. Timothy J, Sloper, Mr. William ...
# 2       2  female  [Nasser, Mrs. Nicholas (Adele Achem), Hewlett,...
# 3       2    male  [Williams, Mr. Charles Eugene, Fynney, Mr. Jos...
# 4       3  female  [Heikkinen, Miss. Laina, Johnson, Mrs. Oscar W...
# 5       3    male  [Braund, Mr. Owen Harris, Allen, Mr. William H...

# %%
train_df.groupby(['Sex', 'Age_group']).count()[['PassengerId']].reset_index()
# Out:
#       Sex Age_group  PassengerId
# 0  female      低年齡層          127
# 1  female      中年齡層          121
# 2  female      高年齡層           13
# 3    male      低年齡層          192
# 4    male      中年齡層          224
# 5    male      高年齡層           37

# %% [markdown]
# ### Dataframe 合併

# %% [markdown]
# #### concat

# %%
train_df = train_df[['PassengerId', 'Name', 'Sex', 'Age']]
upper_df = train_df.loc[0:400, :]
lower_df = train_df.loc[401:, :].reset_index(drop=True)

# %%
print("Upper df:")
upper_df
# Out:
# Upper df:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 396          397                                Olsson, Miss. Elina  female
# 397          398                            McKane, Mr. Peter David    male
# 398          399                                   Pain, Dr. Alfred    male
# 399          400                   Trout, Mrs. William H (Jessie L)  female
# 400          401                                 Niskanen, Mr. Juha    male
#
#      Age
# 0     22
# 1     38
# 2     26
# ...

# %%
print("Lower df:")
lower_df
# Out:
# Lower df:
#      PassengerId                                      Name     Sex  Age
# 0            402                           Adams, Mr. John    male   26
# 1            403                  Jussila, Miss. Mari Aina  female   21
# 2            404            Hakkarainen, Mr. Pekka Pietari    male   28
# 3            405                   Oreskovic, Miss. Marija  female   20
# 4            406                        Gale, Mr. Shadrach    male   34
# ..           ...                                       ...     ...  ...
# 485          887                     Montvila, Rev. Juozas    male   27
# 486          888              Graham, Miss. Margaret Edith  female   19
# 487          889  Johnston, Miss. Catherine Helen "Carrie"  female   20
# 488          890                     Behr, Mr. Karl Howell    male   26
# 489          891                       Dooley, Mr. Patrick    male   32
#
# [490 rows x 4 columns]

# %%
print("Concatenated vertically:")
pd.concat([upper_df, lower_df], ignore_index=True) # ignore index
# Out:
# Concatenated vertically:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#      Age
# 0     22
# ...

# %% [markdown]
# #### merge

# %%
left_df = train_df[['PassengerId', 'Name']]
right_df = train_df[['PassengerId', 'Sex', 'Age']]

# %%
print("Left df:")
left_df
# Out:
# Left df:
#      PassengerId                                               Name
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
print("Right df:")
right_df
# Out:
# Right df:
#      PassengerId     Sex  Age
# 0              1    male   22
# 1              2  female   38
# 2              3  female   26
# 3              4  female   35
# 4              5    male   35
# ..           ...     ...  ...
# 886          887    male   27
# 887          888  female   19
# 888          889  female   20
# 889          890    male   26
# 890          891    male   32
#
# [891 rows x 3 columns]

# %%
pd.merge(left_df, right_df)
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#      Age
# 0     22
# 1     38
# 2     26
# 3     35
# ...
